# %%
#https://www.datacareer.de/blog/accessing-the-news-api-in-python/

import pprint
import requests 

secret = ' ' 


# Define the endpoint
url = 'https://newsapi.org/v2/top-headlines?'


# Specify the query and number of returns
parameters = {
    'q': 'apple', # query phrase
    'pageSize': 20,  # maximum is 100
    'apiKey': secret, # your own API key
    'sortBy': 'popularity'
}


# Make the request
response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'CBS News',
#                'content': 'Watch CBS News\r\n'
#                           'Copyright ©2022 CBS Interactive Inc. All rights '
#                           'reserved.\r\n'
#                           'Get browser notifications for breaking news, live '
#                           'events, and exclusive reporting.\r\n'
#                           'Not NowTurn On',
#                'description': 'Hospitals around the world are dealing with '
#                               'critical shortages of a dye required for '
#                               'certain medical scans and procedures. Some '
#                               'facilities are asking patients to delay '
#                               'elective treatments to conserve the dye for '
#                               'patients who absolutely need it. Elise Preston '
#                               '…',
#                'publishedAt': '2022-05-17T21:40:38+00:00',
#                'source': {'id': 'cbs-news', 'name': 'CBS News'},
#                'title': 'Hospitals grapple with shortage of dye used for CT '
#                         'scans and MRIs',
#                'url': 'https://www.cbsnews.com/video/hospitals-grapple-with-shortage-of-dye-used-for-ct-scans-and-mris/',
#                'urlToImage': 'https://cbsnews1.cbsistatic.com/hub/i/r/2022/05/17/95aeea8a-147b-4107-89a0-0f9022d2bdf7/thumbnail/1200x630/bd44336a06f094471582e445b2cf60b1/0517ctscan-np-1015629-640x360.jpg'},
#               {'author': 'David Chau',
#                'content': 'Australian shares are set to rise sharply in '
#                           'morning trade\xa0following Apple, Tesla and other '
#                           'mega-cap growth stocks driving\xa0a rebound on Wall '
#                           'Street.\r\n'
#                           'ASX futures had gained 1 per cent\xa0to 7,179 '
#                           'points… [+1976 chars]',
#                'description': 'Australian shares are set to rise sharply in '
#                               'morning trade\xa0following Apple, Tesla and '
#                               'other mega-cap growth stocks driving\xa0a '
#                               'rebound on Wall Street.',
#                'publishedAt': '2022-05-17T21:18:03Z',
#                'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#                'title': 'ASX set to jump as tech giants drive Wall Street '
#                         'rebound',
#                'url': 'http://www.abc.net.au/news/2022-05-18/asx-wall-street-rebound-australian-shares/101075692',
#                'urlToImage': 'https://live-production.wcms.abc-cdn.net.au/af9565129f8ba5c1a496397e19ea2171?impolicy=wcms_crop_resize&cropH=1125&cropW=2000&xPos=0&yPos=0&width=862&height=485'},
#               {'author': 'Richard Lawler',
#                'content': 'Employees can choose to continue working remotely '
#                           'for now\r\n'
#                           'Illustration by Alex Castro / The Verge\r\n'
#                           'Apple is delaying moving forward on its hybrid '
#                           'return to work for office employees, saying in a '
#                           'mem… [+2070 chars]',
#                'description': 'Apple had planned to expand its hybrid return '
#                               'to the office pilot, but it will expand the '
#                               '“phase-in” period instead and let people work '
#                               'remotely if they choose. It’s also requiring '
#                               'masking in common areas again.',
#                'publishedAt': '2022-05-17T20:08:26Z',
#                'source': {'id': 'the-verge', 'name': 'The Verge'},
#                'title': 'Apple slows return to office plan, will let employees '
#                         'stay remote and require masks in common spaces',
#                'url': 'https://www.theverge.com/2022/5/17/23100696/apple-delay-hybrid-office-return-work-from-home-covid-19-masks',
#                'urlToImage': 'https://cdn.vox-cdn.com/thumbor/7ptLK_BDo8wD_MW1bD5ZhVFKDWo=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/13728969/acastro_180604_1777_apple_wwdc_0002.jpg'},
#               {'author': 'https://www.engadget.com/about/editors/jon-fingas',
#                'content': 'Apple is once again delaying its return to the '
#                           'office, and this time it will be less strict about '
#                           'in-person work. The New York Timesunderstands that '
#                           'Apple has delayed the return to offices once again… '
#                           '[+1360 chars]',
#                'description': 'Apple has again delayed its return to office, '
#                               "but this time it's friendlier to remote "
#                               'workers..',
#                'publishedAt': '2022-05-17T19:52:24.1844605Z',
#                'source': {'id': 'engadget', 'name': 'Engadget'},
#                'title': 'Apple softens its stance on remote work amid '
#                         'return-to-office delays | Engadget',
#                'url': 'https://www.engadget.com/apple-delays-return-to-office-allows-remote-work-194324892.html',
#                'urlToImage': 'https://s.yimg.com/os/creatr-images/2020-06/f48235f0-a783-11ea-bbfc-3d6d42165a09'},
#               {'author': 'Wired',
#                'content': 'When you turn off an iPhone, it doesnt fully power '
#                           'down. Chips inside the device continue to run in a '
#                           'low-power mode that makes it possible to locate '
#                           'lost or stolen devices using the Find My feature … '
#                           '[+2537 chars]',
#                'description': 'Researchers found a way to exploit the tech '
#                               'that enables Apple’s Find My feature, which '
#                               'could allow attackers to track location when a '
#                               'device is powered down.',
#                'publishedAt': '2022-05-17T19:20:00Z',
#                'source': {'id': 'wired', 'name': 'Wired'},
#                'title': 'Your iPhone Is Vulnerable to a Malware Attack Even '
#                         'When It’s Off',
#                'url': 'https://www.wired.com/story/iphone-find-my-malware-attack-vulnerability',
#                'urlToImage': 'https://media.wired.com/photos/6282eedc0c454f12d5142701/191:100/w_1280,c_limit/Ars-iPhone-Ransomware-GettyImages-1239329854.jpg'},
#               {'author': 'Lance Ulanoff',
#                'content': "Isn't it just like Apple to wait on an emerging "
#                           'technology until it gets good enough to meet its '
#                           'exacting standards? The company is, according to a '
#                           'new report from keen Apple Analyst at TF '
#                           'Internatio… [+3354 chars]',
#                'description': 'A secondary color E Ink display makes perfect '
#                               'sense',
#                'publishedAt': '2022-05-17T16:11:06Z',
#                'source': {'id': 'techradar', 'name': 'TechRadar'},
#                'title': "Here's why Apple should put a color E Ink display on "
#                         'the iPhone 14',
#                'url': 'https://www.techradar.com/news/heres-why-apple-should-put-a-color-e-ink-display-on-the-iphone-14',
#                'urlToImage': 'https://cdn.mos.cms.futurecdn.net/XVAWn2ax5twt72ABJZ8Nva-1200-80.jpg'},
#               {'author': 'Will McCurdy',
#                'content': 'Apple has told App Store developers that they will '
#                           'now be able to automatically pass subscription '
#                           'price rises on to consumers.\r\n'
#                           'Previously, when a subscription price was '
#                           'increased, subscribers had to… [+1432 chars]',
#                'description': 'App Store users better keep an eye on their '
#                               'bank statements',
#                'publishedAt': '2022-05-17T16:05:31Z',
#                'source': {'id': 'techradar', 'name': 'TechRadar'},
#                'title': 'Apple will let App Store developers quietly squeeze '
#                         'you for extra cash',
#                'url': 'https://www.techradar.com/news/apple-will-let-app-store-developers-quietly-squeeze-you-for-extra-cash',
#                'urlToImage': 'https://cdn.mos.cms.futurecdn.net/nYtJ2Rtj5FZxB4qWJQiAF7-1200-80.jpg'},
#               {'author': 'Richard Lawler',
#                'content': 'And lidar-powered Door Detection for compatible '
#                           'devices\r\n'
#                           'Image: Apple\r\n'
#                           'On Tuesday morning, Apple announced a new wave of '
#                           'accessibility features for its various computing '
#                           'platforms, which are set to r… [+5056 chars]',
#                'description': 'Apple announced a wave of new accessibility '
#                               'features on the way. One is Live Caption, which '
#                               'will add subtitles for in-person conversations '
#                               'as well as any audio on the device for Macs, '
#                               'iPhones, and iPads.',
#                'publishedAt': '2022-05-17T14:42:15Z',
#                'source': {'id': 'the-verge', 'name': 'The Verge'},
#                'title': 'Apple devices will transcribe text, look for doors, '
#                         'and learn your doorbell',
#                'url': 'https://www.theverge.com/2022/5/17/23077908/apple-live-captions-door-detection-gesture-ios-macos-watchos-accessibility-day',
#                'urlToImage': 'https://cdn.vox-cdn.com/thumbor/EOof8Mnj1z4sGKDJw3G1ER3tMf0=/0x915:6181x4151/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23515194/apple_accessibileduo.jpg'},
#               {'author': 'https://www.engadget.com/about/editors/christopher-schodt',
#                'content': "We've now tested every version of Apple's M1 "
#                           'processor, from the first M1 chip in the 13-inch '
#                           'Macbook Pro all the way up to the M1 Ultra in the '
#                           "new Mac Studio, and the chip's ability to scale "
#                           'perform… [+1873 chars]',
#                'description': 'We ran every test you could think of on the M1 '
#                               "Ultra to see how fast Apple's new flagship "
#                               'processor really is..',
#                'publishedAt': '2022-05-17T14:37:21.1058797Z',
#                'source': {'id': 'engadget', 'name': 'Engadget'},
#                'title': 'We ran every test you could think of on the M1 Ultra '
#                         '| Engadget',
#                'url': 'https://www.engadget.com/m1-ultra-benchmarks-upscaled-video-143024262.html',
#                'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2022-05/d2a18a60-d51e-11ec-bfd7-1ff38240af6e'},
#               {'author': None,
#                'content': 'March 1 (Reuters) - American big brands including '
#                           'Apple, Google, Ford and Harley-Davidson on Tuesday '
#                           'stopped sales and distanced themselves from Russia '
#                           'because of the invasion of Ukraine, joining a g… '
#                           '[+6542 chars]',
#                'description': 'American big brands including Apple, Google, '
#                               'Ford and Harley-Davidson on Tuesday stopped '
#                               'sales and distanced themselves from Russia '
#                               'because of the invasion of Ukraine, joining a '
#                               'growing list of companies from shippers to car '
#                               'makers to energy companies shunnin…',
#                'publishedAt': '2022-03-01T22:36:13Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'Apple stops product sales in Russia, adding to '
#                         'pressure from shippers, car makers',
#                'url': 'https://www.reuters.com/world/uk/western-companies-pullout-russia-expected-accelerate-2022-03-01/',
#                'urlToImage': 'https://www.reuters.com/resizer/GxIPeP8CVW_362CGS3271BnJNWo=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/5UW4ELYYYRMJDCJTZ6HNEXCZJE.jpg'},
#               {'author': 'GQ',
#                'content': 'Auf eines ist im Frühjahr immer Verlass: Apple '
#                           'präsentiert seine (ersten) neuen Produkte. Glauben '
#                           'wir den jüngsten Gerüchten, wird das auch 2021 so '
#                           'sein und dieses Jahr sogar wieder live aus '
#                           'Cupertin… [+2936 chars]',
#                'description': 'Bald soll es so weit sein: Bei der ersten '
#                               'Keynote 2021 präsentiert Apple Neues aus '
#                               'Cupertino. Auf diese Produkte dürfen wir uns '
#                               'freuen!',
#                'publishedAt': '2021-03-23T17:09:52Z',
#                'source': {'id': 'wired-de', 'name': 'Wired.de'},
#                'title': 'Apple Neuheiten: Was wir vor der ersten Keynote 2021 '
#                         'wissen!',
#                'url': 'https://www.gq-magazin.de/auto-technik/article/apple-neuheiten-2021-das-wissen-wir-vor-keynote',
#                'urlToImage': 'https://res.cloudinary.com/wired-de/image/upload/t_teaser_square/v1/0/apple-neuheiten-event-erste-keynote-2021-technik-aufmjpg.jpg'},
#               {'author': None,
#                'content': "With still no live cricket in sight, we're digging "
#                           'deep into YouTube to keep ourselves entertained. '
#                           'This week, a trip down memory lane with one of the '
#                           'most dominant one-day sides ever - Lancashire in… '
#                           '[+5185 chars]',
#                'description': 'This week, we relive the glorious one-day '
#                               'triumphs of Lancashire in the 1990s | '
#                               'ESPNcricinfo.com',
#                'publishedAt': '2020-04-27T10:24:08Z',
#                'source': {'id': 'espn-cric-info', 'name': 'ESPN Cric Info'},
#                'title': "Akram's yorkers, Hegg's hits, and Chapple's 6 for 18 "
#                         '| ESPNcricinfo.com',
#                'url': 'http://www.espncricinfo.com/story/_/id/29102935/o-my-akram-my-hegg-long-ago',
#                'urlToImage': 'https://a3.espncdn.com/combiner/i?img=%2Fi%2Fcricket%2Fcricinfo%2F1221634_1296x729.jpg'}],
#  'status': 'ok',
#  'totalResults': 12}

# %%
for i in response_json['articles']:
    print(i['title'])
# Out:
# Hospitals grapple with shortage of dye used for CT scans and MRIs
# ASX set to jump as tech giants drive Wall Street rebound
# Apple slows return to office plan, will let employees stay remote and require masks in common spaces
# Apple softens its stance on remote work amid return-to-office delays | Engadget
# Your iPhone Is Vulnerable to a Malware Attack Even When It’s Off
# Here's why Apple should put a color E Ink display on the iPhone 14
# Apple will let App Store developers quietly squeeze you for extra cash
# Apple devices will transcribe text, look for doors, and learn your doorbell
# We ran every test you could think of on the M1 Ultra | Engadget
# Apple stops product sales in Russia, adding to pressure from shippers, car makers
# Apple Neuheiten: Was wir vor der ersten Keynote 2021 wissen!
# Akram's yorkers, Hegg's hits, and Chapple's 6 for 18 | ESPNcricinfo.com

# %%
#!pip install wordcloud

from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Create an empty string
text_combined = ''
# Loop through all the headlines and add them to 'text_combined' 
for i in response_json['articles']:
    text_combined += i['title'] + ' ' # add a space after every headline, so the first and last words are not glued together
# Print the first 300 characters to screen for inspection
print(text_combined[0:300])
# Out:
# Hospitals grapple with shortage of dye used for CT scans and MRIs ASX set to jump as tech giants drive Wall Street rebound Apple slows return to office plan, will let employees stay remote and require masks in common spaces Apple softens its stance on remote work amid return-to-office delays | Engad

# %%
wordcloud = WordCloud(max_font_size=60).generate(text_combined)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
